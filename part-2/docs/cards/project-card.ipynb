# %% [markdown]
# # 🌱 Project Card for Soil Classification Part 2
# ---
# We designed a model for classifying whether an image contains soil or not!
#
# ### 👥 About Us
#
# Our team "Synfire Chain" is named after feed-forward network of neurons, and it consists of 2 members:
# - Yash Kumar, B.S @ IITM
# - Astitva Agarwal, B.S @ IITM
# #### **🏆 We achieved a good F1 score on leaderboard: 0.99 🎯**

# %% [markdown]
# ## Our Metrics
#
# We used ResNet50 and our model converged at `epoch = 2`. We observed setting `learning rate = 0.0001` helped our model converge 3X faster.
#
#
# > All this was made possible only after we balanced training set. Before balacing the F1 ws around 0.6, Once we injected negative data it jumped to 0.99
#
# > Using synthetic data is industry-accepted method to address imbalances
#
# We have the following metrics for our model.

# %% [markdown]
# ### 🎯 Accuracy, Precision and F1 Score over Epoch

# %%
from IPython.display import Image

Image(filename='../assets/acc_precision_f1.png')

# %% [markdown]
# ### 🧮 Confusion Matrix

# %%
Image(filename='../assets/confusion_matrix.png')

# %% [markdown]
# ### 📉 Training v/s Validation Loss

# %%
Image(filename='../assets/loss.png')

# %% [markdown]
# ### PR Curve

# %%
Image(filename='../assets/pr.png')

# %% [markdown]
# ### ⏱️ Training Time

# %%
Image(filename='../assets/training_time.png')

# %% [markdown]
# ### Inferences on Validation Data

# %%
Image(filename='../assets/validation_labelled.png')
